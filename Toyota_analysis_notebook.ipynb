# %% [markdown]
# #Reading the Ingestion Data

# %%
# %sql
USE CATALOG workspace;
USE SCHEMA toyota_project;

SELECT model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize
FROM toyota_raw
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>model</th><th>year</th><th>price</th><th>transmission</th><th>mileage</th><th>fuelType</th><th>tax</th><th>mpg</th><th>engineSize</th></tr></thead><tbody><tr><td> GT86</td><td>2016</td><td>16000</td><td>Manual</td><td>24089</td><td>Petrol</td><td>265</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>15995</td><td>Manual</td><td>18615</td><td>Petrol</td><td>145</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2015</td><td>13998</td><td>Manual</td><td>27469</td><td>Petrol</td><td>265</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>18998</td><td>Manual</td><td>14736</td><td>Petrol</td><td>150</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>17498</td><td>Manual</td><td>36284</td><td>Petrol</td><td>145</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>15998</td><td>Manual</td><td>26919</td><td>Petrol</td><td>260</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>18522</td><td>Manual</td><td>10456</td><td>Petrol</td><td>145</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2017</td><td>18995</td><td>Manual</td><td>12340</td><td>Petrol</td><td>145</td><td>36.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2020</td><td>27998</td><td>Manual</td><td>516</td><td>Petrol</td><td>150</td><td>33.2</td><td>2.0</td></tr><tr><td> GT86</td><td>2016</td><td>13990</td><td>Manual</td><td>37999</td><td>Petrol</td><td>265</td><td>36.2</td><td>2.0</td></tr></tbody></table></div>

# %% [markdown]
# # Loading Raw Data

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA toyota_project")

df_raw = spark.table("toyota_raw")

df_raw.printSchema()
df_raw.show(5)
df_raw.columns
# Out:
# root
#  |-- model: string (nullable = true)
#  |-- year: long (nullable = true)
#  |-- price: long (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- mileage: long (nullable = true)
#  |-- fuelType: string (nullable = true)
#  |-- tax: long (nullable = true)
#  |-- mpg: double (nullable = true)
#  |-- engineSize: double (nullable = true)
#
# +-----+----+-----+------------+-------+--------+---+----+----------+
# |model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|
# +-----+----+-----+------------+-------+--------+---+----+----------+
# | GT86|2016|16000|      Manual|  24089|  Petrol|265|36.2|       2.0|
# | GT86|2017|15995|      Manual|  18615|  Petrol|145|36.2|       2.0|
# | GT86|2015|13998|      Manual|  27469|  Petrol|265|36.2|       2.0|
# | GT86|2017|18998|      Manual|  14736|  Petrol|150|36.2|       2.0|
# | GT86|2017|17498|      Manual|  36284|  Petrol|145|36.2|       2.0|
# +-----+----+-----+------------+-------+--------+---+----+----------+
# only showing top 5 rows
# ['model',
#  'year',
#  'price',
#  'transmission',
#  'mileage',
#  'fuelType',
#  'tax',
#  'mpg',
#  'engineSize']

# %% [markdown]
# #Cleaning & feature engineering
# ## Cast numeric columns & drop bad rows

# %%
from pyspark.sql import functions as F

df = df_raw.select(
    "model", "year", "price", "transmission",
    "mileage", "fuelType", "tax", "mpg", "engineSize"
)

# Cast numerics
df = (
    df.withColumn("year", F.col("year").cast("int"))
      .withColumn("price", F.col("price").cast("double"))
      .withColumn("mileage", F.col("mileage").cast("double"))
      .withColumn("tax", F.col("tax").cast("double"))
      .withColumn("mpg", F.col("mpg").cast("double"))
      .withColumn("engineSize", F.col("engineSize").cast("double"))
)

# Drop rows where key columns are missing or invalid
df = df.dropna(subset=["year", "price", "mileage", "mpg", "engineSize"])

df.show(5)
df.printSchema()
# Out:
# +-----+----+-------+------------+-------+--------+-----+----+----------+
# |model|year|  price|transmission|mileage|fuelType|  tax| mpg|engineSize|
# +-----+----+-------+------------+-------+--------+-----+----+----------+
# | GT86|2016|16000.0|      Manual|24089.0|  Petrol|265.0|36.2|       2.0|
# | GT86|2017|15995.0|      Manual|18615.0|  Petrol|145.0|36.2|       2.0|
# | GT86|2015|13998.0|      Manual|27469.0|  Petrol|265.0|36.2|       2.0|
# | GT86|2017|18998.0|      Manual|14736.0|  Petrol|150.0|36.2|       2.0|
# | GT86|2017|17498.0|      Manual|36284.0|  Petrol|145.0|36.2|       2.0|
# +-----+----+-------+------------+-------+--------+-----+----+----------+
# only showing top 5 rows
# root
#  |-- model: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- mileage: double (nullable = true)
#  |-- fuelType: string (nullable = true)
#  |-- tax: double (nullable = true)
#  |-- mpg: double (nullable = true)
#  |-- engineSize: double (nullable = true)

# %% [markdown]
# # Cleaning & feature engineering
# ## Feature Engineering

# %%
from pyspark.sql import functions as F

# Car age
df = df.withColumn("car_age", F.lit(2020) - F.col("year"))

# Price per mile (safe divide)
df = df.withColumn(
    "price_per_mile",
    F.round(F.try_divide(F.col("price"), F.col("mileage")), 4)
)

# Fuel efficiency index (safe divide)
df = df.withColumn(
    "fuel_efficiency_index",
    F.round(F.try_divide(F.col("mpg"), F.col("engineSize")), 3)
)

# Depreciation score (safe divide)
df = df.withColumn(
    "depreciation_score",
    F.round(F.try_divide(F.col("price"), F.col("car_age")), 3)
)

# Mileage category
df = df.withColumn(
    "mileage_band",
    F.when(F.col("mileage") < 20000, "Low (<20k)")
     .when(F.col("mileage") < 60000, "Medium (20–60k)")
     .when(F.col("mileage") < 100000, "High (60–100k)")
     .otherwise("Very High (>100k)")
)

df.show(10)
# Out:
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# |model|year|  price|transmission|mileage|fuelType|  tax| mpg|engineSize|car_age|price_per_mile|fuel_efficiency_index|depreciation_score|   mileage_band|
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# | GT86|2016|16000.0|      Manual|24089.0|  Petrol|265.0|36.2|       2.0|      4|        0.6642|                 18.1|            4000.0|Medium (20–60k)|
# | GT86|2017|15995.0|      Manual|18615.0|  Petrol|145.0|36.2|       2.0|      3|        0.8593|                 18.1|          5331.667|     Low (<20k)|
# | GT86|2015|13998.0|      Manual|27469.0|  Petrol|265.0|36.2|       2.0|      5|        0.5096|                 18.1|            2799.6|Medium (20–60k)|
# | GT86|2017|18998.0|      Manual|14736.0|  Petrol|150.0|36.2|       2.0|      3|        1.2892|                 18.1|          6332.667|     Low (<20k)|
# | GT86|2017|17498.0|      Manual|36284.0|  Petrol|145.0|36.2|       2.0|      3|        0.4823|                 18.1|          5832.667|Medium (20–60k)|
# | GT86|2017|15998.0|      Manual|26919.0|  Petrol|260.0|36.2|       2.0|      3|        0.5943|                 18.1|          5332.667|Medium (20–60k)|
# | GT86|2017|18522.0|      Manual|10456.0|  Petrol|145.0|36.2|       2.0|      3|        1.7714|                 18.1|            6174.0|     Low (<20k)|
# | GT86|2017|18995.0|      Manual|12340.0|  Petrol|145.0|36.2|       2.0|      3|        1.5393|                 18.1|          6331.667|     Low (<20k)|
# | GT86|2020|27998.0|      Manual|  516.0|  Petrol|150.0|33.2|       2.0|      0|       54.2597|                 16.6|              NULL|     Low (<20k)|
# | GT86|2016|13990.0|      Manual|37999.0|  Petrol|265.0|36.2|       2.0|      4|        0.3682|                 18.1|            3497.5|Medium (20–60k)|
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# only showing top 10 rows

# %% [markdown]
# # Saving Cleaned Data

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA toyota_project")

df.write.format("delta").mode("overwrite").saveAsTable(
    "workspace.toyota_project.toyota_clean"
)

print("Saved as workspace.toyota_project.toyota_clean")
# Out:
# Saved as workspace.toyota_project.toyota_clean

# %% [markdown]
# # Validating cleaned Data

# %%
df_clean = spark.table("workspace.toyota_project.toyota_clean")
df_clean.show(5)
# Out:
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# |model|year|  price|transmission|mileage|fuelType|  tax| mpg|engineSize|car_age|price_per_mile|fuel_efficiency_index|depreciation_score|   mileage_band|
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# | GT86|2016|16000.0|      Manual|24089.0|  Petrol|265.0|36.2|       2.0|      4|        0.6642|                 18.1|            4000.0|Medium (20–60k)|
# | GT86|2017|15995.0|      Manual|18615.0|  Petrol|145.0|36.2|       2.0|      3|        0.8593|                 18.1|          5331.667|     Low (<20k)|
# | GT86|2015|13998.0|      Manual|27469.0|  Petrol|265.0|36.2|       2.0|      5|        0.5096|                 18.1|            2799.6|Medium (20–60k)|
# | GT86|2017|18998.0|      Manual|14736.0|  Petrol|150.0|36.2|       2.0|      3|        1.2892|                 18.1|          6332.667|     Low (<20k)|
# | GT86|2017|17498.0|      Manual|36284.0|  Petrol|145.0|36.2|       2.0|      3|        0.4823|                 18.1|          5832.667|Medium (20–60k)|
# +-----+----+-------+------------+-------+--------+-----+----+----------+-------+--------------+---------------------+------------------+---------------+
# only showing top 5 rows

# %% [markdown]
# #Notebook Analysis
# ## Summary stats

# %%
df_clean.describe().show()
# Out:
# +-------+------+-----------------+-----------------+------------+------------------+--------+-----------------+------------------+-------------------+------------------+------------------+---------------------+------------------+-----------------+
# |summary| model|             year|            price|transmission|           mileage|fuelType|              tax|               mpg|         engineSize|           car_age|    price_per_mile|fuel_efficiency_index|depreciation_score|     mileage_band|
# +-------+------+-----------------+-----------------+------------+------------------+--------+-----------------+------------------+-------------------+------------------+------------------+---------------------+------------------+-----------------+
# |  count|  6738|             6738|             6738|        6738|              6738|    6738|             6738|              6738|               6738|              6738|              6738|                 6732|              6610|             6738|
# |   mean|  NULL|2016.748144850104| 12522.3910655981|        NULL| 22857.41392104482|    NULL|94.69723953695458| 63.04222321163494| 1.4712971208073378|3.2518551498961115| 21.40519021964969|      46.535826054664| 6175.483301210297|             NULL|
# | stddev|  NULL|2.204062053794952|6345.017587050594|        NULL|19125.464146727063|    NULL| 73.8807759955007|15.836710262534993|0.43615863743388056|2.2040620537949547|299.41682294234437|    16.16311362870156| 6600.091276785487|             NULL|
# |    min| Auris|             1998|            850.0|   Automatic|               2.0|  Diesel|              0.0|               2.8|                0.0|                 0|            0.0051|                1.167|            47.316|   High (60–100k)|
# |    max| Yaris|             2020|          59995.0|   Semi-Auto|          174419.0|  Petrol|            565.0|             235.0|                4.5|                22|          11971.25|              130.556|           59995.0|Very High (>100k)|
# +-------+------+-----------------+-----------------+------------+------------------+--------+-----------------+------------------+-------------------+------------------+------------------+---------------------+------------------+-----------------+

# %% [markdown]
# ## Average Price by Fuel Type

# %%
price_fuel = df_clean.groupBy("fuelType") \
        .agg(F.round(F.avg("price"), 2).alias("avg_price")) \
        .orderBy("avg_price")

display(price_fuel)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fuelType</th><th>avg_price</th></tr></thead><tbody><tr><td>Petrol</td><td>9759.54</td></tr><tr><td>Other</td><td>14121.16</td></tr><tr><td>Diesel</td><td>15697.81</td></tr><tr><td>Hybrid</td><td>17185.47</td></tr></tbody></table></div>

# %% [markdown]
# ## Price vs Mileage Relationship

# %%
price_mileage = df_clean.select("price", "mileage", "mileage_band")
display(price_mileage)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>price</th><th>mileage</th><th>mileage_band</th></tr></thead><tbody><tr><td>16000.0</td><td>24089.0</td><td>Medium (20–60k)</td></tr><tr><td>15995.0</td><td>18615.0</td><td>Low (<20k)</td></tr><tr><td>13998.0</td><td>27469.0</td><td>Medium (20–60k)</td></tr><tr><td>18998.0</td><td>14736.0</td><td>Low (<20k)</td></tr><tr><td>17498.0</td><td>36284.0</td><td>Medium (20–60k)</td></tr><tr><td>15998.0</td><td>26919.0</td><td>Medium (20–60k)</td></tr><tr><td>18522.0</td><td>10456.0</td><td>Low (<20k)</td></tr><tr><td>18995.0</td><td>12340.0</td><td>Low (<20k)</td></tr><tr><td>27998.0</td><td>516.0</td><td>Low (<20k)</td></tr><tr><td>13990.0</td><td>37999.0</td><td>Medium (20–60k)</td></tr><tr><td>10495.0</td><td>72000.0</td><td>High (60–100k)</td></tr><tr><td>17990.0</td><td>12597.0</td><td>Low (<20k)</td></tr><tr><td>16995.0</td><td>36100.0</td><td>Medium (20–60k)</td></tr><tr><td>23995.0</td><td>995.0</td><td>Low (<20k)</td></tr><tr><td>18498.0</td><td>35228.0</td><td>Medium (20–60k)</td></tr><tr><td>23980.0</td><td>1751.0</td><td>Low (<20k)</td></tr><tr><td>17995.0</td><td>16444.0</td><td>Low (<20k)</td></tr><tr><td>12998.0</td><td>25499.0</td><td>Medium (20–60k)</td></tr><tr><td>23495.0</td><td>3934.0</td><td>Low (<20k)</td></tr><tr><td>25780.0</td><td>5123.0</td><td>Low (<20k)</td></tr><tr><td>26995.0</td><td>1500.0</td><td>Low (<20k)</td></tr><tr><td>23998.0</td><td>913.0</td><td>Low (<20k)</td></tr><tr><td>26995.0</td><td>2680.0</td><td>Low (<20k)</td></tr><tr><td>17000.0</td><td>14345.0</td><td>Low (<20k)</td></tr><tr><td>19995.0</td><td>15525.0</td><td>Low (<20k)</td></tr><tr><td>31000.0</td><td>3000.0</td><td>Low (<20k)</td></tr><tr><td>15995.0</td><td>19460.0</td><td>Low (<20k)</td></tr><tr><td>18490.0</td><td>31231.0</td><td>Medium (20–60k)</td></tr><tr><td>24990.0</td><td>339.0</td><td>Low (<20k)</td></tr><tr><td>13981.0</td><td>30500.0</td><td>Medium (20–60k)</td></tr><tr><td>13991.0</td><td>38126.0</td><td>Medium (20–60k)</td></tr><tr><td>27060.0</td><td>3348.0</td><td>Low (<20k)</td></tr><tr><td>20695.0</td><td>5260.0</td><td>Low (<20k)</td></tr><tr><td>25999.0</td><td>100.0</td><td>Low (<20k)</td></tr><tr><td>11575.0</td><td>50584.0</td><td>Medium (20–60k)</td></tr><tr><td>20995.0</td><td>6445.0</td><td>Low (<20k)</td></tr><tr><td>14999.0</td><td>18389.0</td><td>Low (<20k)</td></tr><tr><td>27000.0</td><td>100.0</td><td>Low (<20k)</td></tr><tr><td>15000.0</td><td>28321.0</td><td>Medium (20–60k)</td></tr><tr><td>22200.0</td><td>16241.0</td><td>Low (<20k)</td></tr><tr><td>24990.0</td><td>3150.0</td><td>Low (<20k)</td></tr><tr><td>25995.0</td><td>8912.0</td><td>Low (<20k)</td></tr><tr><td>19500.0</td><td>9639.0</td><td>Low (<20k)</td></tr><tr><td>18250.0</td><td>20219.0</td><td>Medium (20–60k)</td></tr><tr><td>23995.0</td><td>1557.0</td><td>Low (<20k)</td></tr><tr><td>17500.0</td><td>14000.0</td><td>Low (<20k)</td></tr><tr><td>23997.0</td><td>4500.0</td><td>Low (<20k)</td></tr><tr><td>17102.0</td><td>21000.0</td><td>Medium (20–60k)</td></tr><tr><td>24995.0</td><td>2488.0</td><td>Low (<20k)</td></tr><tr><td>19995.0</td><td>26000.0</td><td>Medium (20–60k)</td></tr><tr><td>29769.0</td><td>999.0</td><td>Low (<20k)</td></tr><tr><td>25850.0</td><td>4442.0</td><td>Low (<20k)</td></tr><tr><td>13495.0</td><td>24667.0</td><td>Medium (20–60k)</td></tr><tr><td>18495.0</td><td>13930.0</td><td>Low (<20k)</td></tr><tr><td>25499.0</td><td>614.0</td><td>Low (<20k)</td></tr><tr><td>18621.0</td><td>18544.0</td><td>Low (<20k)</td></tr><tr><td>25121.0</td><td>7056.0</td><td>Low (<20k)</td></tr><tr><td>17500.0</td><td>11898.0</td><td>Low (<20k)</td></tr><tr><td>11599.0</td><td>28335.0</td><td>Medium (20–60k)</td></tr><tr><td>17249.0</td><td>10089.0</td><td>Low (<20k)</td></tr><tr><td>25995.0</td><td>3250.0</td><td>Low (<20k)</td></tr><tr><td>13000.0</td><td>39761.0</td><td>Medium (20–60k)</td></tr><tr><td>17250.0</td><td>19420 ...

# %% [markdown]
# ## Engine Size vs MPG

# %%
engine_mpg = df_clean.groupBy("engineSize") \
        .agg(F.round(F.avg("mpg"), 2).alias("avg_mpg")) \
        .orderBy("engineSize")

display(engine_mpg)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>engineSize</th><th>avg_mpg</th></tr></thead><tbody><tr><td>0.0</td><td>64.77</td></tr><tr><td>1.0</td><td>65.04</td></tr><tr><td>1.2</td><td>48.07</td></tr><tr><td>1.3</td><td>55.69</td></tr><tr><td>1.4</td><td>74.52</td></tr><tr><td>1.5</td><td>63.55</td></tr><tr><td>1.6</td><td>55.53</td></tr><tr><td>1.8</td><td>75.84</td></tr><tr><td>2.0</td><td>52.43</td></tr><tr><td>2.2</td><td>45.25</td></tr><tr><td>2.4</td><td>33.4</td></tr><tr><td>2.5</td><td>54.75</td></tr><tr><td>2.8</td><td>33.03</td></tr><tr><td>3.0</td><td>33.75</td></tr><tr><td>4.2</td><td>23.9</td></tr><tr><td>4.5</td><td>29.7</td></tr></tbody></table></div>

# %%
notebook_analysis_chart = df_clean.select(
    "price",
    "mileage",
    "model",
    "fuelType",
    "engineSize"
)

display(notebook_analysis_chart)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>price</th><th>mileage</th><th>model</th><th>fuelType</th><th>engineSize</th></tr></thead><tbody><tr><td>16000.0</td><td>24089.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>15995.0</td><td>18615.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>13998.0</td><td>27469.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18998.0</td><td>14736.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>17498.0</td><td>36284.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>15998.0</td><td>26919.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18522.0</td><td>10456.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18995.0</td><td>12340.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>27998.0</td><td>516.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>13990.0</td><td>37999.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>10495.0</td><td>72000.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>17990.0</td><td>12597.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>16995.0</td><td>36100.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23995.0</td><td>995.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18498.0</td><td>35228.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23980.0</td><td>1751.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>17995.0</td><td>16444.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>12998.0</td><td>25499.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23495.0</td><td>3934.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>25780.0</td><td>5123.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>26995.0</td><td>1500.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23998.0</td><td>913.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>26995.0</td><td>2680.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>17000.0</td><td>14345.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>19995.0</td><td>15525.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>31000.0</td><td>3000.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>15995.0</td><td>19460.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18490.0</td><td>31231.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>24990.0</td><td>339.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>13981.0</td><td>30500.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>13991.0</td><td>38126.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>27060.0</td><td>3348.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>20695.0</td><td>5260.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>25999.0</td><td>100.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>11575.0</td><td>50584.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>20995.0</td><td>6445.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>14999.0</td><td>18389.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>27000.0</td><td>100.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>15000.0</td><td>28321.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>22200.0</td><td>16241.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>24990.0</td><td>3150.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>25995.0</td><td>8912.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>19500.0</td><td>9639.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>18250.0</td><td>20219.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23995.0</td><td>1557.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>17500.0</td><td>14000.0</td><td> GT86</td><td>Petrol</td><td>2.0</td></tr><tr><td>23997.0</td><td>4500.0</td><td ...
# Databricks visualization. Run in Databricks to view.
